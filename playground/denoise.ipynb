# %%
import matplotlib.pyplot as plt

from skimage import img_as_float, filters
from skimage.util import random_noise
from skimage.restoration import denoise_tv_chambolle, denoise_bilateral, denoise_wavelet, estimate_sigma

# %%
img = io.imread('samples/rain_140_1.png')

# %%
plt.imshow(img)

# %%
original = img_as_float(img)
sigma = 0.355
noisy = random_noise(original, var=sigma**2)
sigma_est = estimate_sigma(noisy, multichannel=True, average_sigmas=True)

# %%
plt.imshow(denoise_tv_chambolle(noisy, weight=0.1, multichannel=True))

# %%
edges = filters.sobel(original)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9e6807ea0d06> in <module>
# ----> 1 edges = filters.sobel(original)
#
# ~/.virtualenvs/playground-xrdzk4oU/lib/python3.7/site-packages/skimage/filters/edges.py in sobel(image, mask)
#     101     >>> edges = filters.sobel(camera)
#     102     """
# --> 103     assert_nD(image, 2)
#     104     out = np.sqrt(sobel_h(image, mask)**2 + sobel_v(image, mask)**2)
#     105     out /= np.sqrt(2)
#
# ~/.virtualenvs/playground-xrdzk4oU/lib/python3.7/site-packages/skimage/_shared/utils.py in assert_nD(array, ndim, arg_name)
#     176         raise ValueError(msg_empty_array % (arg_name))
#     177     if not array.ndim in ndim:
# --> 178         raise ValueError(msg_incorrect_dim % (arg_name, '-or-'.join([str(n) for n in ndim])))
#     179
#     180
#
# ValueError: The parameter `image` must be a 2-dimensional array
